# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('mapped_50.csv')
data.head()
# Out:
#    Unnamed: 0  SAUP    Lat    Lon      Gear Targeted Species  \
# 0           1   NaN    NaN    NaN       NaN              NaN
# 1           2  50.0  21.25  88.75  Gillnets    demersal<30cm
# 2           3  50.0  21.75  88.75  Gillnets    demersal<30cm
# 3           4  50.0  22.25  88.75  Gillnets    demersal<30cm
# 4           5  50.0  21.25  89.25  Gillnets    demersal<30cm
#
#   Length_Fishing_Vessel Sector   NomActive   EffActive  No_V_active   Power_V  \
# 0                   NaN    NaN         NaN         NaN          NaN       NaN
# 1                 6-12m    APW  109.466773  112.794563     0.018465  0.533886
# 2                 6-12m    APW  310.062344  319.488240     0.052302  1.512221
# 3                 6-12m    APW  291.724371  300.592791     0.049209  1.422784
# 4                 6-12m    APW  239.821326  247.111894     0.040454  1.169645
#
#    Tonnes_V    Year
# 0       NaN     NaN
# 1  0.080150  1950.0
# 2  0.227023  1950.0
# 3  0.213597  1950.0
# 4  0.175594  1950.0

# %%
data=data.drop('Unnamed: 0',axis=1)
data=data.drop('SAUP',axis=1)
data.head()
# Out:
#      Lat    Lon      Gear Targeted Species Length_Fishing_Vessel Sector  \
# 0    NaN    NaN       NaN              NaN                   NaN    NaN
# 1  21.25  88.75  Gillnets    demersal<30cm                 6-12m    APW
# 2  21.75  88.75  Gillnets    demersal<30cm                 6-12m    APW
# 3  22.25  88.75  Gillnets    demersal<30cm                 6-12m    APW
# 4  21.25  89.25  Gillnets    demersal<30cm                 6-12m    APW
#
#     NomActive   EffActive  No_V_active   Power_V  Tonnes_V    Year
# 0         NaN         NaN          NaN       NaN       NaN     NaN
# 1  109.466773  112.794563     0.018465  0.533886  0.080150  1950.0
# 2  310.062344  319.488240     0.052302  1.512221  0.227023  1950.0
# 3  291.724371  300.592791     0.049209  1.422784  0.213597  1950.0
# 4  239.821326  247.111894     0.040454  1.169645  0.175594  1950.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249680 entries, 0 to 249679
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Lat                    249679 non-null  float64
#  1   Lon                    249679 non-null  float64
#  2   Gear                   249679 non-null  object
#  3   Targeted Species       249679 non-null  object
#  4   Length_Fishing_Vessel  249679 non-null  object
#  5   Sector                 249679 non-null  object
#  6   NomActive              249679 non-null  float64
#  7   EffActive              249679 non-null  float64
#  8   No_V_active            249679 non-null  float64
#  9   Power_V                249679 non-null  float64
#  10  Tonnes_V               249679 non-null  float64
#  11  Year                   249679 non-null  float64
# dtypes: float64(8), object(4)
# memory usage: 22.9+ MB

# %%
data.isnull().sum()
# Out:
# Lat                      1
# Lon                      1
# Gear                     1
# Targeted Species         1
# Length_Fishing_Vessel    1
# Sector                   1
# NomActive                1
# EffActive                1
# No_V_active              1
# Power_V                  1
# Tonnes_V                 1
# Year                     1
# dtype: int64

# %%
data.describe()
# Out:
#                  Lat            Lon      NomActive     EffActive  \
# count  249679.000000  249679.000000  249679.000000  2.496790e+05
# mean       20.761917      86.397573    7497.769005  4.042240e+04
# std         8.999710      27.744102   29858.719928  1.773530e+05
# min       -81.750000    -171.250000       0.000001  1.210000e-05
# 25%        20.250000      89.750000      34.878073  1.450129e+02
# 50%        21.250000      90.750000     426.731901  1.822922e+03
# 75%        22.250000      91.750000    2875.573465  1.324761e+04
# max        76.250000     179.250000  771836.998300  6.225867e+06
#
#         No_V_active       Power_V      Tonnes_V           Year
# count  2.496790e+05  2.496790e+05  2.496790e+05  249679.000000
# mean   4.918044e+00  3.672432e+01  1.256803e+01    1998.810076
# std    2.392621e+01  1.458299e+02  4.861330e+01      15.170317
# min    8.870000e-11  7.130000e-09  7.100000e-10    1950.000000
# 25%    3.651513e-03  1.714642e-01  5.557349e-02    1990.000000
# ...

# %%
y=data[['Lon','Lat']]
print(y)
# Out:
#           Lon    Lat
# 0         NaN    NaN
# 1       88.75  21.25
# 2       88.75  21.75
# 3       88.75  22.25
# 4       89.25  21.25
# ...       ...    ...
# 249675  92.25  20.75
# 249676  92.25  21.25
# 249677  92.25  21.75
# 249678  92.75  20.25
# 249679  92.75  20.75
#
# [249680 rows x 2 columns]

# %%
x=data[['Gear','Targeted Species','Length_Fishing_Vessel','NomActive','EffActive','No_V_active','Power_V','Tonnes_V','Sector']]
print(x)
# Out:
#                  Gear Targeted Species Length_Fishing_Vessel   NomActive  \
# 0                 NaN              NaN                   NaN         NaN
# 1            Gillnets    demersal<30cm                 6-12m  109.466773
# 2            Gillnets    demersal<30cm                 6-12m  310.062344
# 3            Gillnets    demersal<30cm                 6-12m  291.724371
# 4            Gillnets    demersal<30cm                 6-12m  239.821326
# ...               ...              ...                   ...         ...
# 249675  Others_Others        rays<90cm          Less than 6m  686.106970
# 249676  Others_Others        rays<90cm          Less than 6m  270.228494
# 249677  Others_Others        rays<90cm          Less than 6m   40.295047
# 249678  Others_Others        rays<90cm          Less than 6m   11.190635
# 249679  Others_Others        rays<90cm          Less than 6m   48.429758
#
#           EffActive  No_V_active   Power_V  Tonnes_V Sector
# ...

# %%
import category_encoders as ce
encoder=ce.OrdinalEncoder(cols=['Gear','Targeted Species','Length_Fishing_Vessel','Sector'])
x=encoder.fit_transform(x)
x=x.fillna(x.mean())
print(x)
# Out:
#         Gear  Targeted Species  Length_Fishing_Vessel    NomActive  \
# 0          7                 8                      5  7497.769005
# 1          1                 1                      1   109.466773
# 2          1                 1                      1   310.062344
# 3          1                 1                      1   291.724371
# 4          1                 1                      1   239.821326
# ...      ...               ...                    ...          ...
# 249675     6                 7                      2   686.106970
# 249676     6                 7                      2   270.228494
# 249677     6                 7                      2    40.295047
# 249678     6                 7                      2    11.190635
# 249679     6                 7                      2    48.429758
#
#            EffActive  No_V_active    Power_V   Tonnes_V  Sector
# 0       40422.401805     4.918044  36.724318  12.568029       4
# ...

# %%
y.isna().sum()
y=y.fillna(y.mean())
y.isna().sum()
# Out:
# Lon    0
# Lat    0
# dtype: int64

# %%
plt.plot(y['Lon'],y['Lat'])
plt.show()

# %%
plt.scatter(y['Lon'],y['Lat'])
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=43)

# %%
print(x_test)
# Out:
#         Gear  Targeted Species  Length_Fishing_Vessel     NomActive  \
# 52026      2                 1                      2  13887.559610
# 156813     5                 2                      4   3175.026789
# 22281      2                 4                      1      0.314382
# 54594      1                 3                      2  21266.681520
# 63575      3                 1                      2     98.303246
# ...      ...               ...                    ...           ...
# 65622      3                 2                      4   1558.707769
# 115569     4                 3                      1   2678.424076
# 22289      2                 4                      1      3.607450
# 33239      3                 4                      1      0.690656
# 149128     5                 2                      1    239.328556
#
#             EffActive  No_V_active     Power_V   Tonnes_V  Sector
# 52026    44886.320600     4.181853   67.731741  12.287035       1
# ...

# %%
# Linear Regression model
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(x_test)
print(pred)
# Out:
# [[88.44793118 21.20102802]
#  [79.66669603 20.0940324 ]
#  [90.76851643 20.83300105]
#  ...
#  [90.76866706 20.83302573]
#  [88.21894987 20.49464256]
#  [82.02264473 20.33009599]]

# %%
r2_score = model.score(x_test,y_test)
print(r2_score*100,'%')
# Out:
# 1.428976223643058 %

# %%
from sklearn.metrics import recall_score, precision_score, accuracy_score, classification_report, f1_score, r2_score
import numpy as np

# %%
score=r2_score(y_test,pred)
print(score)
# Out:
# 0.014289762236430581

# %%
print("The accuracy of the model is {}% ".format(round(score,2)*100))
# Out:
# The accuracy of the model is 1.0%

# %%
def relative_absolute_error(true, pred):
    true_mean = np.mean(true)
    squared_error_num = np.sum(np.abs(true - pred))
    squared_error_den = np.sum(np.abs(true - true_mean))
    rae_loss = squared_error_num / squared_error_den
    return rae_loss

# %%
def mean_absolute_percentage_error(true, pred):
    abs_error = (np.abs(true - pred)) / true
    sum_abs_error = np.sum(abs_error)
    mape_loss = (sum_abs_error / true.size) * 100
    return mape_loss

# %%
def mean_squared_error(true, pred):
    squared_error = np.square(true - pred) 
    sum_squared_error = np.sum(squared_error)
    mse_loss = sum_squared_error / true.size
    return mse_loss

# %%
def root_mean_squared_error(true, pred):
    squared_error = np.square(true - pred) 
    sum_squared_error = np.sum(squared_error)
    rmse_loss = np.sqrt(sum_squared_error / true.size)
    return rmse_loss

# %%
def relative_squared_error(true, pred):
    true_mean = np.mean(true)
    squared_error_num = np.sum(np.square(true - pred))
    squared_error_den = np.sum(np.square(true - true_mean))
    rse_loss = squared_error_num / squared_error_den
    return rse_loss

# %%
def mean_absolute_percentage_error(true, pred):
    abs_error = (np.abs(true - pred)) / true
    sum_abs_error = np.sum(abs_error)
    mape_loss = (sum_abs_error / true.size) * 100
    return mape_loss

# %%
print(root_mean_squared_error(y_test, pred))
# Out:
# Lon    19.426213
# Lat     6.305137
# dtype: float64
# C:\Users\vinot\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
print(mean_squared_error(y_test, pred))
# Out:
# Lon    377.377745
# Lat     39.754755
# dtype: float64

# %%
print(relative_absolute_error(y_test, pred))
# Out:
# Lon    0.273612
# Lat    0.091361
# dtype: float64

# %%
print(relative_squared_error(y_test, pred))
# Out:
# Lon    0.408124
# Lat    0.068807
# dtype: float64

# %%
print(mean_absolute_percentage_error(y_test, pred))
# Out:
# Lon   -13.384660
# Lat     3.176956
# dtype: float64

# %%
# Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
modell=RandomForestRegressor(max_depth=3,random_state=0)
modell.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=3, random_state=0)

# %%
predd=model.predict(x_test)
print(predd)
# Out:
# [[88.44793118 21.20102802]
#  [79.66669603 20.0940324 ]
#  [90.76851643 20.83300105]
#  ...
#  [90.76866706 20.83302573]
#  [88.21894987 20.49464256]
#  [82.02264473 20.33009599]]

# %%
print(y_test)
# Out:
#            Lon    Lat
# 52026    89.25  20.75
# 156813  128.75  40.25
# 22281    91.25  20.25
# 54594    92.75  20.25
# 63575    88.75  19.75
# ...        ...    ...
# 65622    89.25  22.25
# 115569   89.25  21.75
# 22289    91.75  20.75
# 33239    92.25  19.75
# 149128 -113.25  26.75
#
# [74904 rows x 2 columns]

# %%
scoore=model.score(x_test,y_test)
print(scoore)
# Out:
# 0.014289762236430581

# %%
print(root_mean_squared_error(y_test, pred))
# Out:
# Lon    19.426213
# Lat     6.305137
# dtype: float64
# C:\Users\vinot\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
print(mean_squared_error(y_test, pred))
# Out:
# Lon    377.377745
# Lat     39.754755
# dtype: float64

# %%
print(relative_absolute_error(y_test, pred))
# Out:
# Lon    0.273612
# Lat    0.091361
# dtype: float64

# %%
print(relative_squared_error(y_test, pred))
# Out:
# Lon    0.408124
# Lat    0.068807
# dtype: float64

# %%
def mean_absolute_percentage_error(true, pred):
    abs_error = (np.abs(true - pred)) / true
    sum_abs_error = np.sum(abs_error)
    mape_loss = (sum_abs_error / true.size) * 100
    return mape_loss

# %%
print(mean_absolute_percentage_error(y_test, pred))
# Out:
# Lon   -13.384660
# Lat     3.176956
# dtype: float64

# %%
#KNN model

# %%
from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=1000)
neigh.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=1000)

# %%
pred=neigh.predict(x_test)
print(pred)
# Out:
# [[89.4055 21.2725]
#  [84.9765 20.4605]
#  [90.754  21.093 ]
#  ...
#  [89.867  21.151 ]
#  [90.0765 20.047 ]
#  [85.1165 22.025 ]]

# %%
scoore=model.score(x_test,y_test)
print(scoore)
# Out:
# 0.014289762236430581

# %%
print(root_mean_squared_error(y_test, pred))
# Out:
# Lon    19.335419
# Lat     6.301489
# dtype: float64
# C:\Users\vinot\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
print(mean_squared_error(y_test, pred))
# Out:
# Lon    373.858440
# Lat     39.708763
# dtype: float64

# %%
print(relative_absolute_error(y_test, pred))
# Out:
# Lon    0.258873
# Lat    0.091072
# dtype: float64

# %%
print(relative_squared_error(y_test, pred))
# Out:
# Lon    0.404318
# Lat    0.068728
# dtype: float64

# %%
print(mean_absolute_percentage_error(y_test, pred))
# Out:
# Lon   -15.366795
# Lat     3.270073
# dtype: float64

# %%
#Gradient Regressor

# %%
y_train1= y_train['Lat']
y_train2= y_train['Lon']
print(y_train)
# Out:
#           Lon    Lat
# 150544  91.75  20.25
# 176380  90.75  20.25
# 151088  21.25  57.75
# 108040  88.75  21.75
# 200528  89.75  21.25
# ...       ...    ...
# 125205  90.25  21.25
# 40753   91.25  21.25
# 248063  88.75  21.25
# 150848  91.25  19.75
# 14148   91.75  19.75
#
# [174776 rows x 2 columns]

# %%
y_test1=  y_test['Lat']
y_test2= y_test['Lon']
print(y_test)
# Out:
#            Lon    Lat
# 52026    89.25  20.75
# 156813  128.75  40.25
# 22281    91.25  20.25
# 54594    92.75  20.25
# 63575    88.75  19.75
# ...        ...    ...
# 65622    89.25  22.25
# 115569   89.25  21.75
# 22289    91.75  20.75
# 33239    92.25  19.75
# 149128 -113.25  26.75
#
# [74904 rows x 2 columns]

# %%
from sklearn.ensemble import GradientBoostingRegressor
reg = GradientBoostingRegressor(random_state=0)
reg.fit(x_train, y_train1)
# Out:
# GradientBoostingRegressor(random_state=0)

# %%
from sklearn.ensemble import GradientBoostingRegressor
reg2 = GradientBoostingRegressor(random_state=0)
reg2.fit(x_train, y_train2)
# Out:
# GradientBoostingRegressor(random_state=0)

# %%
pred1=reg.predict(x_test)#lat
pred2=reg2.predict(x_test)#lon

# %%
print(root_mean_squared_error(y_test1, pred1))
print(root_mean_squared_error(y_test2, pred2))
# Out:
# 8.763857391396185
# 26.17896558467675

# %%
print(mean_squared_error(y_test1, pred1))
print(mean_squared_error(y_test2, pred2))
# Out:
# 76.80519637672953
# 685.3382390836897

# %%
print(relative_absolute_error(y_test1, pred1))
print(relative_absolute_error(y_test2, pred2))
# Out:
# 1.0164304525854093
# 0.9143154180590851

# %%
print(relative_squared_error(y_test1, pred1))
print(relative_squared_error(y_test2, pred2))
# Out:
# 0.961951546060292
# 0.8858696818455768

# %%
print(mean_absolute_percentage_error(y_test1, pred1))
print(mean_absolute_percentage_error(y_test2, pred2))
# Out:
# 6.259746086330613
# -20.516019277880844
