# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('ds.csv')
data.head()
# Out:
#    SNO  SAUP    Lat    Lon      Gear Targeted Species Length_Fishing_Vessel  \
# 0    1    50  21.25  88.75  Gillnets    demersal<30cm                 6-12m
# 1    2    50  21.75  88.75  Gillnets    demersal<30cm                 6-12m
# 2    3    50  22.25  88.75  Gillnets    demersal<30cm                 6-12m
# 3    4    50  21.25  89.25  Gillnets    demersal<30cm                 6-12m
# 4    5    50  21.75  89.25  Gillnets    demersal<30cm                 6-12m
#
#   Sector    NomActive    EffActive  No_V_active   Power_V  Tonnes_V  Year
# 0    APW   109.466773   112.794563     0.018465  0.533886  0.080150  1950
# 1    APW   310.062344   319.488240     0.052302  1.512221  0.227023  1950
# 2    APW   291.724371   300.592792     0.049209  1.422784  0.213597  1950
# 3    APW   239.821326   247.111894     0.040454  1.169645  0.175594  1950
# 4    APW  1118.241784  1152.236334     0.188627  5.453835  0.818761  1950

# %%
data=data.drop('SNO',axis=1)
data=data.drop('SAUP',axis=1)
data.head()
# Out:
#      Lat    Lon      Gear Targeted Species Length_Fishing_Vessel Sector  \
# 0  21.25  88.75  Gillnets    demersal<30cm                 6-12m    APW
# 1  21.75  88.75  Gillnets    demersal<30cm                 6-12m    APW
# 2  22.25  88.75  Gillnets    demersal<30cm                 6-12m    APW
# 3  21.25  89.25  Gillnets    demersal<30cm                 6-12m    APW
# 4  21.75  89.25  Gillnets    demersal<30cm                 6-12m    APW
#
#      NomActive    EffActive  No_V_active   Power_V  Tonnes_V  Year
# 0   109.466773   112.794563     0.018465  0.533886  0.080150  1950
# 1   310.062344   319.488240     0.052302  1.512221  0.227023  1950
# 2   291.724371   300.592792     0.049209  1.422784  0.213597  1950
# 3   239.821326   247.111894     0.040454  1.169645  0.175594  1950
# 4  1118.241784  1152.236334     0.188627  5.453835  0.818761  1950

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104513 entries, 0 to 104512
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Lat                    104513 non-null  float64
#  1   Lon                    104513 non-null  float64
#  2   Gear                   104513 non-null  object
#  3   Targeted Species       104513 non-null  object
#  4   Length_Fishing_Vessel  104513 non-null  object
#  5   Sector                 104513 non-null  object
#  6   NomActive              104513 non-null  float64
#  7   EffActive              104513 non-null  float64
#  8   No_V_active            104513 non-null  float64
#  9   Power_V                104513 non-null  float64
#  10  Tonnes_V               104513 non-null  float64
#  11  Year                   104513 non-null  int64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 9.6+ MB

# %%
data.isnull().sum()
# Out:
# Lat                      0
# Lon                      0
# Gear                     0
# Targeted Species         0
# Length_Fishing_Vessel    0
# Sector                   0
# NomActive                0
# EffActive                0
# No_V_active              0
# Power_V                  0
# Tonnes_V                 0
# Year                     0
# dtype: int64

# %%
data.describe()
# Out:
#                  Lat            Lon      NomActive     EffActive  \
# count  104513.000000  104513.000000  104513.000000  1.045130e+05
# mean       21.142162      90.744991   14690.892447  7.997698e+04
# std         0.951662       1.168957   44014.140480  2.610607e+05
# min        19.250000      88.750000       0.000051  1.604450e-04
# 25%        20.250000      89.750000     137.694316  4.535131e+02
# 50%        21.250000      90.750000    1264.201381  4.972151e+03
# 75%        21.750000      91.750000    7663.320381  3.407321e+04
# max        22.750000      92.750000  771836.998327  5.869084e+06
#
#         No_V_active       Power_V      Tonnes_V           Year
# count  1.045130e+05  1.045130e+05  1.045130e+05  104513.000000
# mean   4.382689e+00  7.188666e+01  2.088104e+01    1999.284548
# std    1.598272e+01  2.148880e+02  6.780526e+01      14.640480
# min    2.113195e-09  2.527314e-07  4.556266e-08    1950.000000
# 25%    9.043031e-03  6.774100e-01  1.605243e-01    1991.000000
# 50%    9.851078e-02  6.213425e+00  1.566513e+00    2002.000000
# 75%    1.250875e+00  3.755874e+01  9.781247e+00    2011.000000
# max    3.261049e+02  3.764366e+03  1.415392e+03    2017.000000

# %%
y=data[['Lon','Lat']]
print(y)
# Out:
#           Lon    Lat
# 0       88.75  21.25
# 1       88.75  21.75
# 2       88.75  22.25
# 3       89.25  21.25
# 4       89.25  21.75
# ...       ...    ...
# 104508  92.25  21.25
# 104509  92.25  21.75
# 104510  92.75  19.75
# 104511  92.75  20.25
# 104512  92.75  20.75
#
# [104513 rows x 2 columns]

# %%
x=data[['Gear','Targeted Species','Length_Fishing_Vessel','NomActive','EffActive','No_V_active','Power_V','Tonnes_V','Sector']]
print(x)
# Out:
#                    Gear Targeted Species Length_Fishing_Vessel    NomActive  \
# 0              Gillnets    demersal<30cm                 6-12m   109.466773
# 1              Gillnets    demersal<30cm                 6-12m   310.062344
# 2              Gillnets    demersal<30cm                 6-12m   291.724371
# 3              Gillnets    demersal<30cm                 6-12m   239.821326
# 4              Gillnets    demersal<30cm                 6-12m  1118.241784
# ...                 ...              ...                   ...          ...
# 104508  Lines_Longlines        rays<90cm          Less than 6m   247.353774
# 104509  Lines_Longlines        rays<90cm          Less than 6m    95.938324
# 104510  Lines_Longlines        rays<90cm          Less than 6m    27.387532
# 104511  Lines_Longlines        rays<90cm          Less than 6m    92.942430
# 104512  Lines_Longlines        rays<90cm          Less than 6m   116.993551
#
#           EffActive  No_V_active   Power_V  Tonnes_V Sector
# 0        112.794563     0.018465  0.533886  0.080150    APW
# 1        319.488240     0.052302  1.512221  0.227023    APW
# 2        300.592792     0.049209  1.422784  0.213597    APW
# 3        247.111894     0.040454  1.169645  0.175594    APW
# 4       1152.236334     0.188627  5.453835  0.818761    APW
# ...             ...          ...       ...       ...    ...
# 104508  1074.476739     0.054939  1.206382  0.161630    APW
# 104509   416.745201     0.021309  0.467906  0.062690    APW
# 104510   118.968334     0.006083  0.133573  0.017896    APW
# 104511   403.731377     0.020643  0.453294  0.060732    APW
# 104512   508.206716     0.025985  0.570595  0.076448    APW
#
# [104513 rows x 9 columns]

# %%
import category_encoders as ce
encoder=ce.OrdinalEncoder(cols=['Gear','Targeted Species','Length_Fishing_Vessel','Sector'])
x=encoder.fit_transform(x)
x=x.fillna(x.mean())
print(x)
# Out:
#         Gear  Targeted Species  Length_Fishing_Vessel    NomActive  \
# 0          1                 1                      1   109.466773
# 1          1                 1                      1   310.062344
# 2          1                 1                      1   291.724371
# 3          1                 1                      1   239.821326
# 4          1                 1                      1  1118.241784
# ...      ...               ...                    ...          ...
# 104508     2                 7                      2   247.353774
# 104509     2                 7                      2    95.938324
# 104510     2                 7                      2    27.387532
# 104511     2                 7                      2    92.942430
# 104512     2                 7                      2   116.993551
#
#           EffActive  No_V_active   Power_V  Tonnes_V  Sector
# 0        112.794563     0.018465  0.533886  0.080150       1
# 1        319.488240     0.052302  1.512221  0.227023       1
# 2        300.592792     0.049209  1.422784  0.213597       1
# 3        247.111894     0.040454  1.169645  0.175594       1
# 4       1152.236334     0.188627  5.453835  0.818761       1
# ...             ...          ...       ...       ...     ...
# 104508  1074.476739     0.054939  1.206382  0.161630       1
# 104509   416.745201     0.021309  0.467906  0.062690       1
# 104510   118.968334     0.006083  0.133573  0.017896       1
# 104511   403.731377     0.020643  0.453294  0.060732       1
# 104512   508.206716     0.025985  0.570595  0.076448       1
#
# [104513 rows x 9 columns]

# %%
y.isna().sum()
y=y.fillna(y.mean())
y.isna().sum()
# Out:
# Lon    0
# Lat    0
# dtype: int64

# %%
plt.plot(y['Lon'],y['Lat'])
plt.show()

# %%
plt.scatter(y['Lon'],y['Lat'])
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=43)

# %%
print(x_test)
# Out:
#        Gear  Targeted Species  Length_Fishing_Vessel      NomActive  \
# 27725     3                 2                      4      79.465981
# 93204     2                 4                      3       0.960220
# 55861     1                 4                      4     929.575788
# 26164     3                 3                      1    9144.479137
# 4776      2                 1                      2       0.268615
# ...     ...               ...                    ...            ...
# 58503     1                 2                      1  141313.200225
# 53912     3                 2                      1    5574.927284
# 79956     2                 3                      2   14989.642525
# 99533     1                 5                      2   13819.436934
# 17798     2                 1                      3      34.689577
#
#            EffActive  No_V_active     Power_V    Tonnes_V  Sector
# 27725     288.026735     0.000557    0.391151    0.164951       1
# 93204       3.979103     0.000040    0.004776    0.000777       1
# 55861    4826.213769     0.008341    4.624154    1.596979       1
# 26164   32166.564117     3.164855   44.599016   13.762631       1
# 4776        0.413605     0.000189    0.001310    0.000553       1
# ...              ...          ...         ...         ...     ...
# 58503  755980.046099    51.839880  689.205972  225.655616       1
# 53912   28090.217891     1.974984   27.189768    8.598301       1
# 79956   57543.671054     4.746486   73.106767   13.961104       1
# 99533  102773.772724     3.405166   67.399496   10.017930       1
# 17798      84.169880     0.002338    0.170512    0.035319       1
#
# [31354 rows x 9 columns]

# %%
# Linear Regression model
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(x_test)
print(pred)
# Out:
# [[90.71756527 21.07575217]
#  [90.7620651  21.17220696]
#  [90.73567029 21.11704584]
#  ...
#  [90.75878405 21.17130232]
#  [90.78389858 21.22260166]
#  [90.63921112 20.95241412]]

# %%
r2_score = model.score(x_test,y_test)
print(r2_score*100,'%')
# Out:
# 2.018967534593641 %

# %%
from sklearn.metrics import recall_score, precision_score, accuracy_score, classification_report, f1_score, r2_score
import numpy as np

# %%
score=r2_score(y_test,pred)
print(score)
# Out:
# 0.02018967534593641

# %%
print("The accuracy of the model is {}% ".format(round(score,2)*100))
# Out:
# The accuracy of the model is 2.0%

# %%
def relative_absolute_error(true, pred):
    true_mean = np.mean(true)
    squared_error_num = np.sum(np.abs(true - pred))
    squared_error_den = np.sum(np.abs(true - true_mean))
    rae_loss = squared_error_num / squared_error_den
    return rae_loss

# %%
def mean_absolute_percentage_error(true, pred):
    abs_error = (np.abs(true - pred)) / true
    sum_abs_error = np.sum(abs_error)
    mape_loss = (sum_abs_error / true.size) * 100
    return mape_loss

# %%
def mean_squared_error(true, pred):
    squared_error = np.square(true - pred) 
    sum_squared_error = np.sum(squared_error)
    mse_loss = sum_squared_error / true.size
    return mse_loss

# %%
def root_mean_squared_error(true, pred):
    squared_error = np.square(true - pred) 
    sum_squared_error = np.sum(squared_error)
    rmse_loss = np.sqrt(sum_squared_error / true.size)
    return rmse_loss

# %%
def relative_squared_error(true, pred):
    true_mean = np.mean(true)
    squared_error_num = np.sum(np.square(true - pred))
    squared_error_den = np.sum(np.square(true - true_mean))
    rse_loss = squared_error_num / squared_error_den
    return rse_loss

# %%
def mean_absolute_percentage_error(true, pred):
    abs_error = (np.abs(true - pred)) / true
    sum_abs_error = np.sum(abs_error)
    mape_loss = (sum_abs_error / true.size) * 100
    return mape_loss

# %%
print(root_mean_squared_error(y_test, pred))
# Out:
# Lon    0.824087
# Lat    0.660686
# dtype: float64
# C:\Users\vinot\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
print(mean_squared_error(y_test, pred))
# Out:
# Lon    0.679120
# Lat    0.436506
# dtype: float64

# %%
print(relative_absolute_error(y_test, pred))
# Out:
# Lon    0.028378
# Lat    0.022859
# dtype: float64

# %%
print(relative_squared_error(y_test, pred))
# Out:
# Lon    0.00112
# Lat    0.00072
# dtype: float64

# %%
print(mean_absolute_percentage_error(y_test, pred))
# Out:
# Lon    0.544593
# Lat    1.888068
# dtype: float64

# %%
# Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
modell=RandomForestRegressor(max_depth=3,random_state=0)
modell.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=3, random_state=0)

# %%
predd=model.predict(x_test)
print(predd)
# Out:
# [[90.71756527 21.07575217]
#  [90.7620651  21.17220696]
#  [90.73567029 21.11704584]
#  ...
#  [90.75878405 21.17130232]
#  [90.78389858 21.22260166]
#  [90.63921112 20.95241412]]

# %%
print(y_test)
# Out:
#          Lon    Lat
# 27725  88.75  20.75
# 93204  88.75  21.25
# 55861  91.25  21.75
# 26164  91.75  21.75
# 4776   89.75  19.75
# ...      ...    ...
# 58503  91.75  22.25
# 53912  91.75  22.25
# 79956  89.75  22.25
# 99533  92.25  20.25
# 17798  90.25  22.75
#
# [31354 rows x 2 columns]

# %%
scoore=model.score(x_test,y_test)
print(scoore)
# Out:
# 0.02018967534593641

# %%
print(root_mean_squared_error(y_test, pred))
# Out:
# Lon    0.824087
# Lat    0.660686
# dtype: float64
# C:\Users\vinot\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
print(mean_squared_error(y_test, pred))
# Out:
# Lon    0.679120
# Lat    0.436506
# dtype: float64

# %%
print(relative_absolute_error(y_test, pred))
# Out:
# Lon    0.028378
# Lat    0.022859
# dtype: float64

# %%
print(relative_squared_error(y_test, pred))
# Out:
# Lon    0.00112
# Lat    0.00072
# dtype: float64

# %%
def mean_absolute_percentage_error(true, pred):
    abs_error = (np.abs(true - pred)) / true
    sum_abs_error = np.sum(abs_error)
    mape_loss = (sum_abs_error / true.size) * 100
    return mape_loss

# %%
print(mean_absolute_percentage_error(y_test, pred))
# Out:
# Lon    0.544593
# Lat    1.888068
# dtype: float64

# %%
#KNN model

# %%
from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=1000)
neigh.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=1000)

# %%
pred=neigh.predict(x_test)
print(pred)
# Out:
# [[90.6245 21.047 ]
#  [90.9565 21.2585]
#  [90.749  21.153 ]
#  ...
#  [90.849  21.335 ]
#  [90.766  21.2505]
#  [90.648  20.976 ]]

# %%
scoore=model.score(x_test,y_test)
print(scoore)
# Out:
# 0.02018967534593641

# %%
print(root_mean_squared_error(y_test, pred))
# Out:
# Lon    0.824620
# Lat    0.640156
# dtype: float64
# C:\Users\vinot\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
print(mean_squared_error(y_test, pred))
# Out:
# Lon    0.679998
# Lat    0.409800
# dtype: float64

# %%
print(relative_absolute_error(y_test, pred))
# Out:
# Lon    0.028382
# Lat    0.022051
# dtype: float64

# %%
print(relative_squared_error(y_test, pred))
# Out:
# Lon    0.001121
# Lat    0.000676
# dtype: float64

# %%
print(mean_absolute_percentage_error(y_test, pred))
# Out:
# Lon    0.544688
# Lat    1.818625
# dtype: float64

# %%
#Gradient Regressor

# %%
y_train1= y_train['Lat']
y_train2= y_train['Lon']
print(y_train)
# Out:
#          Lon    Lat
# 72556  89.25  20.25
# 11093  90.25  19.25
# 20657  91.25  21.75
# 78466  92.25  19.75
# 70889  90.25  22.25
# ...      ...    ...
# 57651  91.75  21.25
# 83984  92.75  20.75
# 40753  91.25  21.75
# 19776  92.75  20.75
# 14148  91.75  20.25
#
# [73159 rows x 2 columns]

# %%
y_test1=  y_test['Lat']
y_test2= y_test['Lon']
print(y_test)
# Out:
#          Lon    Lat
# 27725  88.75  20.75
# 93204  88.75  21.25
# 55861  91.25  21.75
# 26164  91.75  21.75
# 4776   89.75  19.75
# ...      ...    ...
# 58503  91.75  22.25
# 53912  91.75  22.25
# 79956  89.75  22.25
# 99533  92.25  20.25
# 17798  90.25  22.75
#
# [31354 rows x 2 columns]

# %%
from sklearn.ensemble import GradientBoostingRegressor
reg = GradientBoostingRegressor(random_state=0)
reg.fit(x_train, y_train1)
# Out:
# GradientBoostingRegressor(random_state=0)

# %%
from sklearn.ensemble import GradientBoostingRegressor
reg2 = GradientBoostingRegressor(random_state=0)
reg2.fit(x_train, y_train2)
# Out:
# GradientBoostingRegressor(random_state=0)

# %%
pred1=reg.predict(x_test)#lat
pred2=reg2.predict(x_test)#lon

# %%
print(root_mean_squared_error(y_test1, pred1))
print(root_mean_squared_error(y_test2, pred2))
# Out:
# 0.8596898599008118
# 1.149582553869608

# %%
print(mean_squared_error(y_test1, pred1))
print(mean_squared_error(y_test2, pred2))
# Out:
# 0.7390666552162775
# 1.3215400481613702

# %%
print(relative_absolute_error(y_test1, pred1))
print(relative_absolute_error(y_test2, pred2))
# Out:
# 0.8940110027863837
# 0.986870236690805

# %%
print(relative_squared_error(y_test1, pred1))
print(relative_squared_error(y_test2, pred2))
# Out:
# 0.8184455448991779
# 0.9660159525918178

# %%
print(mean_absolute_percentage_error(y_test1, pred1))
print(mean_absolute_percentage_error(y_test2, pred2))
# Out:
# 3.4224204766315838
# 1.0724612714088015
